# %%
import numpy as np
import json_tricks

# -- placeholder start --
np.random.seed(42)

def is_obfuscated():
    return '__pyarmor__' in globals()

if not is_obfuscated():
    inputs = {}
    inputs['task1'] = [{'N': x} for x in range(3, 14)]
    inputs['task2'] = [{'N': x} for x in range(3, 14)]
    inputs['task3'] = [{'N': x} for x in range(3, 14)]
    inputs['task4'] = [{'order': np.random.permutation(x)} for x in range(3, 14)]
    inputs['task5'] = [{'phi': np.random.rand(1)[0] for x in range(10)}]

    import os
    os.makedirs('inputs', exist_ok=True)
    json_tricks.dump(inputs, 'inputs/inputs.json')
# -- placeholder end --

inputs = json_tricks.load('inputs/inputs.json')
answer = {}

# %% [markdown]
# # Inversion Matrix
#
# Write a code that generates a matrix that inverses the
# order of coordinates of a vector in $N$-dimenional space:
#
# $$
# \begin{bmatrix}
# x_1 \\
# \vdots \\
# x_N
# \end{bmatrix}
# \rightarrow
# A
# \rightarrow
# \begin{bmatrix}
# x_N \\
# \vdots \\
# x_1
# \end{bmatrix}
# $$

# %%
def inversion_matrix(N):
    res = np.zeros([N, N])
    ## YOUR CODE HERE
    # -- placeholder start --
    res = np.eye(N)
    res = res[:, ::-1]
    # -- placeholder end --

    return res

# %%
# Let us check, how does it work

x = np.arange(5)
print('x:', x)
print('Ax:', inversion_matrix(5) @ x)

# %%
answer['task1'] = []
for one_input in inputs['task1']:
    answer['task1'].append(inversion_matrix(**one_input))

# %% [markdown]
# # Rolling Sum Matrix
#
# Write a code that generates a matrix that performs
# rolling sum of coordinates of a vector in $N$-dimenional
# space:
#
# $$
# \begin{bmatrix}
# x_1 \\
# x_2 \\
# \vdots \\
# x_N
# \end{bmatrix}
# \rightarrow
# A
# \rightarrow
# \begin{bmatrix}
# x_1 \\
# x_1 + x_2 \\
# \vdots \\
# x_1 + x_2 + \dots + x_N
# \end{bmatrix}
# $$

# %%
def rolling_sum_matrix(N):
    res = np.zeros([N, N])
    ## YOUR CODE HERE
    # -- placeholder start --
    res = np.tril(np.ones([N, N]))
    # -- placeholder end --

    return res

# %%
# Let us check, how does it work

x = np.arange(5)
print('x:', x)
print('Ax:', rolling_sum_matrix(5) @ x)

# %%
answer['task2'] = []
for one_input in inputs['task2']:
    answer['task2'].append(rolling_sum_matrix(**one_input))

# %% [markdown]
# # Neighbors Difference Matrix
#
# Write a code that generates a matrix that computes a vector
# with difference of adjacent elements of the original vector
# order of coordinates of a vector in $N$-dimenional space:
#
# $$
# \begin{bmatrix}
# x_1 \\
# \vdots \\
# x_N
# \end{bmatrix}
# \rightarrow
# A
# \rightarrow
# \begin{bmatrix}
# x_2 - x_1 \\
# \vdots \\
# x_N - x_{N-1}
# \end{bmatrix}
# $$

# %%
def neighbors_difference_matrix(N):
    res = np.zeros([N, N])
    ## YOUR CODE HERE
    # -- placeholder start --
    res = np.diag([1] * (N - 1), k=1) - np.eye(N, N)
    res = res[:N-1, :]
    # -- placeholder end --
    return res

# %%
# Let us check, how does it work

x = np.arange(5)
print('x:', x)
print('Ax:', neighbors_difference_matrix(5) @ x)

# %%
answer['task3'] = []
for one_input in inputs['task3']:
    answer['task3'].append(neighbors_difference_matrix(**one_input))

# %% [markdown]
# # Permutation Matrix
#
# You are given a permutation $\sigma$ (order, the permuted
# elements should go in).
#
# Write a program that generates a matrix that permutes
# coordinates in vector:
#
# $$
# \begin{bmatrix}
# x_1 \\
# x_2 \\
# \vdots \\
# x_N
# \end{bmatrix}
# \rightarrow
# A
# \rightarrow
# \begin{bmatrix}
# x_{\sigma_1} \\
# x_{\sigma_2} \\
# \vdots \\
# x_{\sigma_N}
# \end{bmatrix}
# $$
#
# For example, if you are given a permutation $\sigma = (3, 4, 2, 1)$,
# the resulting vector should have the following form:
#
# $$[x_3, x_4, x_2, x_1]^T$$

# %%
def permutation_matrix(order):
    N = len(order)
    res = np.zeros([N, N])
    ## YOUR CODE HERE
    # -- placeholder start --
    res[np.arange(len(order)), order] = 1
    # -- placeholder end --

    return res

# %%
# Let us check, how does it work

order = np.random.permutation(5)
x = np.arange(5)
print('x:', x)
print('order:', order)
print('Ax:', permutation_matrix(order) @ x)

# %%
answer['task4'] = []
for one_input in inputs['task4']:
    answer['task4'].append(permutation_matrix(**one_input))

# %% [markdown]
# # 2D Rotation Matrix
#
# Write a code that, given the angle $\theta$, generates a
# matrix that rotates any 2D vector by angle $\theta$ counterclockwise without changing its length.

# %%
def rotation_2D_matrix(phi):
    res = np.zeros([2, 2])
    ## YOUR CODE HERE
    # -- placeholder start --
    res[0, 0] = np.cos(phi)
    res[0, 1] = - np.sin(phi)
    res[1, 0] = np.sin(phi)
    res[1, 1] = np.cos(phi)
    # -- placeholder end --

    return res

# %%
# Let us check, how does it work

order = np.random.permutation(5)
x = np.array([1, 1])

print('x:', x)
print('order:', order)
print('Ax:', rotation_2D_matrix(np.pi / 4) @ x)

# %%
answer['task5'] = []
for one_input in inputs['task5']:
    answer['task5'].append(rotation_2D_matrix(**one_input))

# %%
json_tricks.dump(answer, '.answer.json')

# %%
# -- placeholder start --
## THIS PART ENCRYPTS THE SCRIPT TO PYARMOR
import os
import shutil

import sys

def is_obfuscated():
    return '__pyarmor__' in globals()

if is_obfuscated(): 
    print("Running an obfuscated script.")
else:
    print("Running outside of obfuscated script.")
    os.system(f"jupyter nbconvert --to script task.ipynb")
    py_file = 'task.py'
    os.system(f"pyarmor gen task.py --platform windows.x86_64,darwin.x86_64,darwin.arm64,linux.x86_64,linux.aarch64")
    os.remove('task.py')
    print(f"Obfuscated file created: {py_file}")
# -- placeholder end --
